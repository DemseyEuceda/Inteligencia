# %%
import pandas as pd

df = pd.read_csv("cuadros.csv")

df1= pd.read_json("csvjson.json")
df1["nota final"] = (df1["EMTC"]+ df1["__1"]+ df1["__2"]+ df1["__3"]+ df1["__4"]+ df1["__5"]+ df1["__6"]+ df1["__7"]+ df1["__8"]+ df1["__9"]+ df1["__10"])/3
df1["pasados"] = (df1["nota final"]>64.5)
df2 = df.join(df1)
df2
# Out:
#    Unnamed: 0  EVALUACIONES    1    2    3    4    5    6    7    8  ...  \
# 0           #  N° de cuenta  10%  10%  18%   6%  10%  16%  10%  10%  ...
# 1           1   20111001220   NP   NP   NP   NP   NP   NP   NP   NP  ...
# 2           2   20111011524    9   10   13    4    9   13   10    7  ...
# 3           3   20121014514   10   10   13    4    9   13   10    7  ...
# 4           4   20121014779    9   10   13    4    9   13    0    7  ...
# 5           5   20121900096    6   10   13    4    9   13   10    7  ...
# 6           6   20131014704    9   10   13    4    9   13   10    7  ...
# 7           7   20151000626    0    0   13    0    0    0    0    0  ...
# 8           8   20151020418   NP   NP   NP   NP   NP   NP   NP   NP  ...
# 9           9   20151022586    9   10   13    4    9   13   10    7  ...
# 10         10   20151023908   10   10   13    4    9   13   10    7  ...
# 11         11   20151030932    9   10   16    6    9   13   10    8  ...
# ...
